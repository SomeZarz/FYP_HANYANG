# %% [markdown]
# # Environment Setup

# %%
# --- MacOS Validator ---
import sys
sys.path.insert(0, './setup_validation')

from macos_validator import main
results = main(run_benchmark=False)

#  --- Path Setup ---
import torch
from pathlib import Path

project_root = Path.cwd()
sys.path.insert(0, './src')
# Out:
# === DEPENDENCY STATUS ===
#  ✓ h5py                 v3.15.1         HDF5 file format support
#  ✓ matplotlib           v3.10.7         Plotting library
#  ✓ memory_profiler      v0.61.0         Memory profiling tool
#  ✓ numpy                v1.26.4         Numerical computing library
#  ✓ pandas               v2.3.3          Data manipulation library
#  ✓ scipy                v1.16.3         Scientific computing library
#  ✓ seaborn              v0.13.2         Statistical visualization library
#  ✓ sklearn              v1.7.2          Scikit-learn ML library
#  ✓ torch                v2.9.1          PyTorch deep learning framework
#  ✓ torchaudio           v2.9.1          PyTorch audio utilities
#  ✓ torchvision          v0.24.1         PyTorch vision utilities
#  ✓ tqdm                 v4.67.1         Progress bar library
#  ✓ yaml                 v6.0.3          Config manipulation library
#
# === GPU/ACCELERATOR STATUS ===
# Platform: arm64
# Apple Silicon: Yes
#
# PyTorch MPS:
#  Installed: Yes
#  Version: 2.9.1
#  MPS Available: Yes
#  Device: mps
#
# Recommended Device: MPS
#
# === HDF5 I/O TEST ===
# Working: ✓ Yes

# %% [markdown]
# # Data Process & H5 Packaging

# %%
# -- Paper Feature Extrction --
from src.data_process import cleanup_corrupted_files, extraction_pipeline

config = "config.yaml"
cleanup_corrupted_files(config)
extraction_pipeline(config)
# Out:
# ✓ File OK, skipping: /Users/zarz/Code/FYP_HANYANG/data_extracted/data_paper_sample.h5
# 🗑 Deleted: /Users/zarz/Code/FYP_HANYANG/data_extracted/data_paper_sample_checkpoint.json
# Cleanup complete. You can now re-run the pipeline.
# Data profile: data_paper
#
# Found 300 vehicle files
# Processing: 100%|██████████| 300/300 [01:38<00:00,  3.04it/s]
# ==================================================
# ✅ Processing Complete
# ==================================================
# Total vehicles processed: 300
# Successful extractions: 4
# No valid segments: 296
# Errors: 0
# Total samples extracted: 4
# ==================================================
# HDF5 file closed safely

# %%
# -- Paper Feature Extrction --
from src.data_process import cleanup_corrupted_files, extraction_pipeline

config = "config.yaml"
cleanup_corrupted_files(config)
extraction_pipeline(config)
# Out:
# ✓ File OK, skipping: /Users/zarz/Code/FYP_HANYANG/data_extracted/data_modified_sample.h5
# 🗑 Deleted: /Users/zarz/Code/FYP_HANYANG/data_extracted/data_modified_sample_checkpoint.json
# Cleanup complete. You can now re-run the pipeline.
# Data profile: data_modified
#
# Found 300 vehicle files
# Processing: 100%|██████████| 300/300 [02:07<00:00,  2.36it/s]
# ==================================================
# ✅ Processing Complete
# ==================================================
# Total vehicles processed: 300
# Successful extractions: 59
# No valid segments: 241
# Errors: 0
# Total samples extracted: 95
# ==================================================
# HDF5 file closed safely

# %% [markdown]
# # Training

# %%
from src.train import model_pipeline

config = "config.yaml"
model_pipeline(config)
# Out:
# Data profile: model_paper
# Training for 100 epochs with patience 10
# Device: mps
# Model parameters: 6,926,564
# Epoch 1/100
# Train MSE: 0.2466 | Val MSE: 0.0037 | Val MAE: 0.0510 | Val RMSE: 0.0607 | Val MAPE: 9.55%
# ✓ New best model saved (MAPE: 9.55%)
# Epoch 2/100
# Train MSE: 0.0513 | Val MSE: 0.0220 | Val MAE: 0.1433 | Val RMSE: 0.1483 | Val MAPE: 23.66%
#   Patience: 1/10
# Epoch 3/100
# Train MSE: 0.0411 | Val MSE: 0.0143 | Val MAE: 0.1134 | Val RMSE: 0.1198 | Val MAPE: 18.53%
#   Patience: 2/10
# Epoch 4/100
# Train MSE: 0.0234 | Val MSE: 0.0025 | Val MAE: 0.0357 | Val RMSE: 0.0496 | Val MAPE: 5.29%
# ✓ New best model saved (MAPE: 5.29%)
# Epoch 5/100
# Train MSE: 0.0093 | Val MSE: 0.0021 | Val MAE: 0.0393 | Val RMSE: 0.0454 | Val MAPE: 7.30%
#   Patience: 1/10
# Epoch 6/100
# Train MSE: 0.0028 | Val MSE: 0.0114 | Val MAE: 0.1059 | Val RMSE: 0.1066 | Val MAPE: 18.46%
#   Patience: 2/10
# Epoch 7/100
# Train MSE: 0.0013 | Val MSE: 0.0236 | Val MAE: 0.1538 | Val RMSE: 0.1538 | Val MAPE: 26.44%
#   Patience: 3/10
# Epoch 8/100
# Train MSE: 0.0016 | Val MSE: 0.0354 | Val MAE: 0.1880 | Val RMSE: 0.1881 | Val MAPE: 32.14%
#   Patience: 4/10
# Epoch 9/100
# Train MSE: 0.0004 | Val MSE: 0.0465 | Val MAE: 0.2152 | Val RMSE: 0.2157 | Val MAPE: 36.59%
#   Patience: 5/10
# Epoch 10/100
# Train MSE: 0.0009 | Val MSE: 0.0602 | Val MAE: 0.2444 | Val RMSE: 0.2453 | Val MAPE: 41.41%
#   Patience: 6/10
# Epoch 11/100
# Train MSE: 0.0010 | Val MSE: 0.0750 | Val MAE: 0.2722 | Val RMSE: 0.2738 | Val MAPE: 45.97%
#   Patience: 7/10
# Epoch 12/100
# Train MSE: 0.0001 | Val MSE: 0.0901 | Val MAE: 0.2976 | Val RMSE: 0.3001 | Val MAPE: 50.10%
#   Patience: 8/10
# Epoch 13/100
# Train MSE: 0.0004 | Val MSE: 0.1040 | Val MAE: 0.3191 | Val RMSE: 0.3225 | Val MAPE: 53.62%
#   Patience: 9/10
# Epoch 14/100
# Train MSE: 0.0004 | Val MSE: 0.1104 | Val MAE: 0.3274 | Val RMSE: 0.3322 | Val MAPE: 54.82%
#   Patience: 10/10
#
# Early stopping triggered after 10 epochs without improvement
#
# Training completed. Best validation MAPE: 5.29%
# Evaluating: 100%|██████████| 1/1 [00:06<00:00,  6.31s/it]
# ==================================================
# TEST SET EVALUATION
# ==================================================
# MSE:  0.080195
# MAE:  0.282946
# RMSE: 0.283187
# MAPE: 52.41%
#
# Average modality attention:
#   Voltage Map: 0.329
#   Sequence:    0.406
#   Point Features: 0.265
# (FusionModelResNet(
#    (map_net): SmallResNet2D(
#      (stem): Sequential(
#        (0): Conv2d(1, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#        (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): ReLU()
#        (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#      )
#      (block1): ResidualBlock2D(
#        (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block2): ResidualBlock2D(
#        (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#          (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block3): ResidualBlock2D(
#        (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#          (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block4): ResidualBlock2D(
#        (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#          (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#      (fc): Linear(in_features=512, out_features=128, bias=True)
#    )
#    (seq_net): ResNet1D(
#      (stem): Sequential(
#        (0): Conv1d(2, 32, kernel_size=(7,), stride=(2,), padding=(3,), bias=False)
#        (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): ReLU()
#      )
#      (block1): ResidualBlock1D(
#        (conv1): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#        (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#        (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv1d(32, 64, kernel_size=(1,), stride=(1,), bias=False)
#          (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block2): ResidualBlock1D(
#        (conv1): Conv1d(64, 128, kernel_size=(3,), stride=(2,), padding=(1,), bias=False)
#        (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#        (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv1d(64, 128, kernel_size=(1,), stride=(2,), bias=False)
#          (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block3): ResidualBlock1D(
#        (conv1): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,), bias=False)
#        (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#        (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv1d(128, 256, kernel_size=(1,), stride=(2,), bias=False)
#          (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block4): ResidualBlock1D(
#        (conv1): Conv1d(256, 512, kernel_size=(3,), stride=(2,), padding=(1,), bias=False)
#        (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#        (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv1d(256, 512, kernel_size=(1,), stride=(2,), bias=False)
#          (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (avgpool): AdaptiveAvgPool1d(output_size=1)
#      (fc): Linear(in_features=512, out_features=128, bias=True)
#    )
#    (pt_net): PointMLP(
#      (net): Sequential(
#        (0): Linear(in_features=15, out_features=64, bias=True)
#        (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): ReLU()
#        (3): Linear(in_features=64, out_features=128, bias=True)
#        (4): ReLU()
#      )
#    )
#    (fusion_head): ModalityAwareFusionHead(
#      (attention): Sequential(
#        (0): Linear(in_features=384, out_features=64, bias=True)
#        (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): ReLU()
#        (3): Linear(in_features=64, out_features=3, bias=True)
#      )
#      (regression): Sequential(
#        (0): Linear(in_features=384, out_features=256, bias=True)
#        (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): ReLU()
#        (3): Linear(in_features=256, out_features=128, bias=True)
#        (4): ReLU()
#        (5): Linear(in_features=128, out_features=1, bias=True)
#      )
#    )
#  ),
#  {'mse': 0.0801946222782135,
#   'mae': 0.2829456925392151,
#   'rmse': 0.28318655490875244,
#   'mape': 52.40773010253906,
#   'predictions': array([0.23943418, 0.27526116], dtype=float32),
#   'targets': array([0.51070285, 0.5698839 ], dtype=float32),
#   'attention_scores': array([[0.332457  , 0.4088343 , 0.2587087 ],
#          [0.32490653, 0.40359324, 0.27150032]], dtype=float32)})

# %%
from src.train import model_pipeline

config = "config.yaml"
model_pipeline(config)
# Out:
# Data profile: model_modified
# Training for 50 epochs with patience 5
# Device: mps
# Model parameters: 6,926,564
# Epoch 1/50
# Train MSE: 0.1565 | Val MSE: 0.2851 | Val MAE: 0.5217 | Val RMSE: 0.5339 | Val MAPE: 78.74%
# ✓ New best model saved (MAPE: 78.74%)
# Epoch 2/50
# Train MSE: 0.0224 | Val MSE: 0.1447 | Val MAE: 0.3635 | Val RMSE: 0.3804 | Val MAPE: 54.08%
# ✓ New best model saved (MAPE: 54.08%)
# Epoch 3/50
# Train MSE: 0.0114 | Val MSE: 0.0324 | Val MAE: 0.1457 | Val RMSE: 0.1799 | Val MAPE: 20.34%
# ✓ New best model saved (MAPE: 20.34%)
# Epoch 4/50
# Train MSE: 0.0055 | Val MSE: 0.0203 | Val MAE: 0.1135 | Val RMSE: 0.1423 | Val MAPE: 15.82%
# ✓ New best model saved (MAPE: 15.82%)
# Epoch 5/50
# Train MSE: 0.0051 | Val MSE: 0.0065 | Val MAE: 0.0657 | Val RMSE: 0.0805 | Val MAPE: 9.49%
# ✓ New best model saved (MAPE: 9.49%)
# Epoch 6/50
# Train MSE: 0.0041 | Val MSE: 0.0023 | Val MAE: 0.0386 | Val RMSE: 0.0479 | Val MAPE: 6.04%
# ✓ New best model saved (MAPE: 6.04%)
# Epoch 7/50
# Train MSE: 0.0026 | Val MSE: 0.0018 | Val MAE: 0.0309 | Val RMSE: 0.0424 | Val MAPE: 4.71%
# ✓ New best model saved (MAPE: 4.71%)
# Epoch 8/50
# Train MSE: 0.0025 | Val MSE: 0.0014 | Val MAE: 0.0296 | Val RMSE: 0.0370 | Val MAPE: 4.60%
# ✓ New best model saved (MAPE: 4.60%)
# Epoch 9/50
# Train MSE: 0.0021 | Val MSE: 0.0015 | Val MAE: 0.0288 | Val RMSE: 0.0381 | Val MAPE: 4.40%
# ✓ New best model saved (MAPE: 4.40%)
# Epoch 10/50
# Train MSE: 0.0018 | Val MSE: 0.0008 | Val MAE: 0.0211 | Val RMSE: 0.0274 | Val MAPE: 3.23%
# ✓ New best model saved (MAPE: 3.23%)
# Epoch 11/50
# Train MSE: 0.0015 | Val MSE: 0.0010 | Val MAE: 0.0247 | Val RMSE: 0.0322 | Val MAPE: 3.88%
#   Patience: 1/5
# Epoch 12/50
# Train MSE: 0.0018 | Val MSE: 0.0012 | Val MAE: 0.0246 | Val RMSE: 0.0349 | Val MAPE: 3.83%
#   Patience: 2/5
# Epoch 13/50
# Train MSE: 0.0026 | Val MSE: 0.0018 | Val MAE: 0.0260 | Val RMSE: 0.0424 | Val MAPE: 4.05%
#   Patience: 3/5
# Epoch 14/50
# Train MSE: 0.0013 | Val MSE: 0.0020 | Val MAE: 0.0281 | Val RMSE: 0.0449 | Val MAPE: 4.38%
#   Patience: 4/5
# Epoch 15/50
# Train MSE: 0.0022 | Val MSE: 0.0013 | Val MAE: 0.0283 | Val RMSE: 0.0356 | Val MAPE: 4.51%
#   Patience: 5/5
#
# Early stopping triggered after 5 epochs without improvement
#
# Training completed. Best validation MAPE: 3.23%
# Evaluating: 100%|██████████| 3/3 [00:11<00:00,  3.90s/it]
# ==================================================
# TEST SET EVALUATION
# ==================================================
# MSE:  0.001419
# MAE:  0.029356
# RMSE: 0.037667
# MAPE: 4.62%
#
# Average modality attention:
#   Voltage Map: 0.370
#   Sequence:    0.325
#   Point Features: 0.304
# (FusionModelResNet(
#    (map_net): SmallResNet2D(
#      (stem): Sequential(
#        (0): Conv2d(1, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#        (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): ReLU()
#        (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#      )
#      (block1): ResidualBlock2D(
#        (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block2): ResidualBlock2D(
#        (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#          (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block3): ResidualBlock2D(
#        (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#          (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block4): ResidualBlock2D(
#        (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#        (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#          (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#      (fc): Linear(in_features=512, out_features=128, bias=True)
#    )
#    (seq_net): ResNet1D(
#      (stem): Sequential(
#        (0): Conv1d(2, 32, kernel_size=(7,), stride=(2,), padding=(3,), bias=False)
#        (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): ReLU()
#      )
#      (block1): ResidualBlock1D(
#        (conv1): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#        (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#        (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv1d(32, 64, kernel_size=(1,), stride=(1,), bias=False)
#          (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block2): ResidualBlock1D(
#        (conv1): Conv1d(64, 128, kernel_size=(3,), stride=(2,), padding=(1,), bias=False)
#        (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#        (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv1d(64, 128, kernel_size=(1,), stride=(2,), bias=False)
#          (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block3): ResidualBlock1D(
#        (conv1): Conv1d(128, 256, kernel_size=(3,), stride=(2,), padding=(1,), bias=False)
#        (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#        (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv1d(128, 256, kernel_size=(1,), stride=(2,), bias=False)
#          (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (block4): ResidualBlock1D(
#        (conv1): Conv1d(256, 512, kernel_size=(3,), stride=(2,), padding=(1,), bias=False)
#        (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#        (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (skip): Sequential(
#          (0): Conv1d(256, 512, kernel_size=(1,), stride=(2,), bias=False)
#          (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        )
#      )
#      (avgpool): AdaptiveAvgPool1d(output_size=1)
#      (fc): Linear(in_features=512, out_features=128, bias=True)
#    )
#    (pt_net): PointMLP(
#      (net): Sequential(
#        (0): Linear(in_features=15, out_features=64, bias=True)
#        (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): ReLU()
#        (3): Linear(in_features=64, out_features=128, bias=True)
#        (4): ReLU()
#      )
#    )
#    (fusion_head): ModalityAwareFusionHead(
#      (attention): Sequential(
#        (0): Linear(in_features=384, out_features=64, bias=True)
#        (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): ReLU()
#        (3): Linear(in_features=64, out_features=3, bias=True)
#      )
#      (regression): Sequential(
#        (0): Linear(in_features=384, out_features=256, bias=True)
#        (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): ReLU()
#        (3): Linear(in_features=256, out_features=128, bias=True)
#        (4): ReLU()
#        (5): Linear(in_features=128, out_features=1, bias=True)
#      )
#    )
#  ),
#  {'mse': 0.0014188402565196157,
#   'mae': 0.029355989769101143,
#   'rmse': 0.037667494267225266,
#   'mape': 4.6224846839904785,
#   'predictions': array([0.88215923, 0.6839016 , 0.68331504, 0.6507385 , 0.5082725 ,
#          0.69111824, 0.8798012 , 0.59456295, 0.5855144 , 0.64315593,
#          0.7238123 , 0.77946556, 0.5229387 , 0.7591325 , 0.57454103,
#          0.7164822 , 0.62351835, 0.69320416, 0.8771174 , 0.59456295,
#          0.70063984, 0.48375437, 0.64315593, 0.56498444, 0.4362392 ,
#          0.78519475, 0.56696355, 0.5411304 , 0.5130229 , 0.6691743 ,
#          0.6792092 , 0.7043074 , 0.7256799 , 0.50368345, 0.6792084 ,
#          0.5810717 , 0.57094705, 0.7123493 , 0.668785  , 0.7166106 ,
#          0.61300457, 0.56837153, 0.4362392 , 0.46807557, 0.6933495 ,
#          0.77946556, 0.78519475, 0.7591325 , 0.53754807, 0.6691743 ,
#          0.6989328 , 0.6839016 , 0.68331504, 0.6792092 , 0.69320416,
#          0.8771174 , 0.5321593 , 0.5082725 , 0.6965174 , 0.77448595,
#          0.4558352 , 0.7043074 , 0.7164822 , 0.50368345, 0.6792093 ,
#          0.6235182 , 0.8771176 , 0.7907015 , 0.7314285 , 0.53081816,
#          0.61300457, 0.6006417 , 0.7074262 , 0.68323565, 0.72381234,
#          0.52293885, 0.5411304 ], dtype=float32),
#   'targets': array([0.86207974, 0.7267412 , 0.70283943, 0.6515018 , 0.50896055,
#          0.7324575 , 0.81668496, 0.615948  , 0.5631665 , 0.6246794 ,
#          0.7563722 , 0.7980263 , 0.56263584, 0.6839593 , 0.58896005,
#          0.67879534, 0.62777954, 0.71126556, 0.839738  , 0.615948  ,
#          0.68432206, 0.5487925 , 0.6246794 , 0.52169263, 0.5024608 ,
#          0.7808631 , 0.56479806, 0.5337217 , 0.5877572 , 0.7093308 ,
#          0.63503855, 0.66753566, 0.7170561 , 0.50986254, 0.63503855,
#          0.5957923 , 0.6098968 , 0.5702939 , 0.6848991 , 0.7206921 ,
#          0.6345683 , 0.5931982 , 0.5024608 , 0.501824  , 0.7005226 ,
#          0.7980263 , 0.7808631 , 0.6839593 , 0.5132007 , 0.7093308 ,
#          0.713954  , 0.7267412 , 0.70283943, 0.63503855, 0.71126556,
#          0.839738  , 0.54267615, 0.50896055, 0.7590043 , 0.7738964 ,
#          0.5166387 , 0.66753566, 0.67879534, 0.50986254, 0.63503855,
#          0.62777954, 0.839738  , 0.7861482 , 0.7226835 , 0.549645  ,
#          0.6345683 , 0.56199926, 0.73508495, 0.70563495, 0.7563722 ,
#          0.56263584, 0.5337217 ], dtype=float32),
#   'attention_scores': array([[0.48561838, 0.10835927, 0.4060223 ],
#          [0.4341017 , 0.36744577, 0.19845252],
#          [0.54919755, 0.3042268 , 0.14657561],
#          [0.3904744 , 0.32474068, 0.28478494],
#          [0.35265502, 0.3595447 , 0.28780022],
#          [0.4520208 , 0.260476  , 0.28750324],
#          [0.3277829 , 0.46393988, 0.20827724],
#          [0.33994114, 0.35755908, 0.3024998 ],
#          [0.28155473, 0.23725031, 0.48119494],
#          [0.3766975 , 0.41390425, 0.20939827],
#          [0.3664392 , 0.31499732, 0.31856343],
#          [0.34588507, 0.3011909 , 0.35292396],
#          [0.41766685, 0.3189159 , 0.26341727],
#          [0.32051462, 0.35988653, 0.31959888],
#          [0.27909046, 0.34704247, 0.37386703],
#          [0.3834481 , 0.42339823, 0.19315362],
#          [0.21582192, 0.3737069 , 0.41047117],
#          [0.34201974, 0.35783657, 0.30014378],
#          [0.31105053, 0.35635492, 0.3325946 ],
#          [0.33994114, 0.35755908, 0.3024998 ],
#          [0.30503255, 0.2147899 , 0.48017752],
#          [0.25810096, 0.42508668, 0.31681225],
#          [0.3766975 , 0.41390425, 0.20939827],
#          [0.3443318 , 0.34038013, 0.315288  ],
#          [0.30595678, 0.42222205, 0.27182126],
#          [0.37816003, 0.29007104, 0.33176896],
#          [0.32895917, 0.32003993, 0.35100085],
#          [0.39268818, 0.2812097 , 0.32610208],
#          [0.21421462, 0.38904962, 0.39673576],
#          [0.49090233, 0.27782285, 0.23127471],
#          [0.3432276 , 0.17592977, 0.48084262],
#          [0.36238432, 0.4587634 , 0.17885226],
#          [0.30463716, 0.3204637 , 0.37489912],
#          [0.610706  , 0.19281553, 0.1964786 ],
#          [0.3432339 , 0.17592663, 0.48083946],
#          [0.2199121 , 0.44480142, 0.3352864 ],
#          [0.4026539 , 0.32325858, 0.27408752],
#          [0.88383603, 0.07451835, 0.04164555],
#          [0.2625104 , 0.35839203, 0.37909752],
#          [0.44205806, 0.30270997, 0.25523198],
#          [0.34187555, 0.3078856 , 0.35023886],
#          [0.5033916 , 0.26697624, 0.22963208],
#          [0.30595678, 0.42222205, 0.27182126],
#          [0.3057771 , 0.42779258, 0.26643032],
#          [0.32484183, 0.3761827 , 0.29897547],
#          [0.34588507, 0.3011909 , 0.35292396],
#          [0.37816003, 0.29007104, 0.33176896],
#          [0.32051462, 0.35988653, 0.31959888],
#          [0.26912394, 0.29601374, 0.43486232],
#          [0.49090233, 0.27782285, 0.23127471],
#          [0.29572728, 0.4408093 , 0.2634634 ],
#          [0.4341017 , 0.36744577, 0.19845252],
#          [0.54919755, 0.3042268 , 0.14657561],
#          [0.3432276 , 0.17592977, 0.48084262],
#          [0.34201974, 0.35783657, 0.30014378],
#          [0.31105053, 0.35635492, 0.3325946 ],
#          [0.27396682, 0.33068317, 0.39535004],
#          [0.35265502, 0.3595447 , 0.28780022],
#          [0.37911856, 0.30278292, 0.31809846],
#          [0.36743185, 0.39148656, 0.24108166],
#          [0.29845473, 0.44784042, 0.25370488],
#          [0.36238432, 0.4587634 , 0.17885226],
#          [0.3834481 , 0.42339823, 0.19315362],
#          [0.610706  , 0.19281553, 0.1964786 ],
#          [0.34322754, 0.17592977, 0.48084265],
#          [0.21582194, 0.3737068 , 0.4104712 ],
#          [0.31105042, 0.35635492, 0.3325946 ],
#          [0.32406336, 0.31262857, 0.36330813],
#          [0.4106947 , 0.26810277, 0.32120255],
#          [0.44820076, 0.29733592, 0.25446334],
#          [0.34187543, 0.30788553, 0.350239  ],
#          [0.4786486 , 0.33674613, 0.1846053 ],
#          [0.2778055 , 0.29748064, 0.42471385],
#          [0.41996107, 0.25595465, 0.32408434],
#          [0.3664392 , 0.31499732, 0.3185635 ],
#          [0.4176669 , 0.3189159 , 0.26341718],
#          [0.39268827, 0.28120968, 0.32610202]], dtype=float32)})
